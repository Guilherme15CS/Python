# %%
#Pegar os dados de uma base de dados e colocar dentro de um site 

#Passo 1: Fazer passo a passo do que fazer manualmente
    #Fazer o login no site (Com gmail e senha)
    #Cadastrar produtos

#Passo 2: importar bibliotecas e salvar a base de dados

#Passo3: Analisar a base de dados
    #Ver se tem algum erro

#Passo 4: Fazer o código para automatizar o processo

# %%
#Passo 2: importar bibliotecas e salvar a base de dados

import pyautogui
import pandas as pd
from time import sleep
tabela = pd.read_csv(r'C:\Users\lcamp\OneDrive\Documentos\VS CODE\Python\Hashtag\Aula1\produtos.csv')


#Passo3: Analisar a base de dados
    #Ver se tem algum erro
display(tabela)
# Out:
#          codigo       marca        tipo  categoria  preco_unitario  custo  \
# 0    MOLO000251    Logitech       Mouse          1           25.95    6.5
# 1    MOLO000192    Logitech       Mouse          2           19.95    5.0
# 2    CAHA000251     Hashtag      Camisa          1           25.00   11.0
# 3    CAHA000252     Hashtag      Camisa          2           25.00   11.0
# 4    MOMU000111  Multilaser       Mouse          1           11.99    3.4
# ..          ...         ...         ...        ...             ...    ...
# 288  ACAP000192       Apple  Acessorios          2           19.00    3.8
# 289  ACSA0009.3     Samsung  Acessorios          3            9.55    2.1
# 290  CEMO000271    Motorola     Celular          1          279.00   72.5
# 291  FOMO000152    Motorola        Fone          2          150.00   33.0
# 292  CEMO000223    Motorola     Celular          3          229.00   55.0
#
#                   obs
# 0                 NaN
# 1                 NaN
# ...

# %%
sleep(5)  
pyautogui.position()
# Out:
# Point(x=699, y=323)

# %%
#Passo 4: Fazer o código para automatizar o processo

pyautogui.PAUSE = 0.75

#Entrando no site
pyautogui.press('win')
pyautogui.write('chrome')
pyautogui.press('enter')
pyautogui.write('https://dlp.hashtagtreinamentos.com/python/intensivao/login')
pyautogui.press('enter')

#Fazer login (gmail e senha)
pyautogui.press('tab')
pyautogui.write('guicseleg@gmail.com')
pyautogui.press('tab')
pyautogui.write('123456789')
pyautogui.press('enter')

#Cadastrar produtos


for linha in tabela.index:
    codigos = tabela['codigo'][linha]
    marcas = tabela['marca'][linha]
    tipo = tabela['tipo'][linha]
    categoria = tabela['categoria'][linha]
    categoria = str(categoria)
    preco_unitario = tabela['preco_unitario'][linha]
    preco_unitario = str(preco_unitario)
    custo = tabela['custo'][linha]
    custo = str(custo)
    obs = tabela['obs'][linha]
    obs = str(obs)
    print(codigos)
    pyautogui.click(x=699, y=323)
    pyautogui.write(codigos)
    pyautogui.press('tab')
    pyautogui.write(marcas)
    pyautogui.press('tab')
    pyautogui.write(tipo)
    pyautogui.press('tab')  
    pyautogui.write(categoria)
    pyautogui.press('tab')
    pyautogui.write(preco_unitario)
    pyautogui.press('tab')
    pyautogui.write(custo)
    pyautogui.press('tab')
    if obs != 'nan':
        pyautogui.write(obs)
    pyautogui.press('tab')
    pyautogui.press('enter')

    #Voltar paro o começo da pagina
    pyautogui.scroll(100000)
# Out:
# MOLO000251
# MOLO000192
# CAHA000251
# CAHA000252
# MOMU000111
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# Cell In[34], line 36
#      34 print(codigos)
#      35 pyautogui.click(x=699, y=323)
# ---> 36 pyautogui.write(codigos)
#      37 pyautogui.press('tab')
#      38 pyautogui.write(marcas)
#
# File c:\Users\lcamp\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyautogui\__init__.py:593, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     591 @functools.wraps(wrappedFunction)
#     592 def wrapper(*args, **kwargs):
# --> 593     failSafeCheck()
#     594     returnVal = wrappedFunction(*args, **kwargs)
#     595     _handlePause(kwargs.get("_pause", True))
#
# File c:\Users\lcamp\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyautogui\__init__.py:1734, in failSafeCheck()
#    1732 def failSafeCheck():
# ...
