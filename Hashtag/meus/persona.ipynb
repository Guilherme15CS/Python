# %%
#Passo 1 Importar base de dados

import pandas as pd

tabela = pd.read_csv(r"C:\Users\lcamp\OneDrive\Documentos\VS CODE\Python\Hashtag\meus\personality_dataset.csv")

display(tabela)
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0                  4.0         No                      4.0            6.0
# 1                  9.0        Yes                      0.0            0.0
# 2                  9.0        Yes                      1.0            2.0
# 3                  0.0         No                      6.0            7.0
# 4                  3.0         No                      9.0            4.0
# ...                ...        ...                      ...            ...
# 2895               3.0         No                      7.0            6.0
# 2896               3.0         No                      8.0            3.0
# 2897               4.0        Yes                      1.0            1.0
# 2898              11.0        Yes                      1.0            NaN
# 2899               3.0         No                      6.0            6.0
#
#      Drained_after_socializing  Friends_circle_size  Post_frequency  \
# ...

# %%
#Passo 2 Analisar a base de dados
#Ver dados faltantes

tabela.info()

tabela = tabela.dropna()
tabela.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2900 entries, 0 to 2899
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time_spent_Alone           2837 non-null   float64
#  1   Stage_fear                 2827 non-null   object
#  2   Social_event_attendance    2838 non-null   float64
#  3   Going_outside              2834 non-null   float64
#  4   Drained_after_socializing  2848 non-null   object
#  5   Friends_circle_size        2823 non-null   float64
#  6   Post_frequency             2835 non-null   float64
#  7   Personality                2900 non-null   object
# dtypes: float64(5), object(3)
# memory usage: 181.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2477 entries, 0 to 2899
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
# ...

# %%
# Comparar Introvertidos e Extrovertidos
display(tabela["Personality"].value_counts())

display(tabela["Personality"].value_counts(normalize=True))
# Out:
# Personality
# Extrovert    1274
# Introvert    1203
# Name: count, dtype: int64
# Personality
# Extrovert    0.514332
# Introvert    0.485668
# Name: proportion, dtype: float64

# %%
#Passo 3 ver pontos semelhantes
import plotly.express as px

for coluna in tabela.columns:


    grafico = px.histogram(tabela, x=coluna, color='Personality')

    grafico.show()
